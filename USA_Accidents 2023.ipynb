# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("US_Accidents_March23.csv")

# %%
df.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0   False  False           False          False        False          Night
# 1   False  False           False          False        False          Night
# 2   False  False           False           True        False          Night
# 3   False  False           False          False        False          Night
# 4   False  False           False           True        False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0          Night             Night                 Night
# 1          Night             Night                   Day
# 2          Night               Day                   Day
# 3            Day               Day                   Day
# 4            Day               Day                   Day
#
# [5 rows x 46 columns]

# %%
df.tail()
# Out:
#                 ID   Source  Severity           Start_Time  \
# 7728389  A-7777757  Source1         2  2019-08-23 18:03:25
# 7728390  A-7777758  Source1         2  2019-08-23 19:11:30
# 7728391  A-7777759  Source1         2  2019-08-23 19:00:21
# 7728392  A-7777760  Source1         2  2019-08-23 19:00:21
# 7728393  A-7777761  Source1         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat  Start_Lng   End_Lat    End_Lng  \
# 7728389  2019-08-23 18:32:01   34.00248 -117.37936  33.99888 -117.37094
# 7728390  2019-08-23 19:38:23   32.76696 -117.14806  32.76555 -117.15363
# 7728391  2019-08-23 19:28:49   33.77545 -117.84779  33.77740 -117.85727
# 7728392  2019-08-23 19:29:42   33.99246 -118.40302  33.98311 -118.39565
# 7728393  2019-08-23 19:21:31   34.13393 -117.23092  34.13736 -117.23934
#
#          Distance(mi)  ... Roundabout Station   Stop Traffic_Calming  \
# 7728389         0.543  ...      False   False  False           False
# 7728390         0.338  ...      False   False  False           False
# 7728391         0.561  ...      False   False  False           False
# 7728392         0.772  ...      False   False  False           False
# 7728393         0.537  ...      False   False  False           False
#
#         Traffic_Signal Turning_Loop Sunrise_Sunset Civil_Twilight  \
# 7728389          False        False            Day            Day
# 7728390          False        False            Day            Day
# 7728391          False        False            Day            Day
# 7728392          False        False            Day            Day
# 7728393          False        False            Day            Day
#
#         Nautical_Twilight Astronomical_Twilight
# 7728389               Day                   Day
# 7728390               Day                   Day
# 7728391               Day                   Day
# 7728392               Day                   Day
# 7728393               Day                   Day
#
# [5 rows x 46 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
print(df.shape[0])
print(df.shape[1])
# Out:
# 7728394
# 46

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  7.728394e+06  7.728394e+06  7.728394e+06  4.325632e+06  4.325632e+06
# mean   2.212384e+00  3.620119e+01 -9.470255e+01  3.626183e+01 -9.572557e+01
# std    4.875313e-01  5.076079e+00  1.739176e+01  5.272905e+00  1.810793e+01
# min    1.000000e+00  2.455480e+01 -1.246238e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.339963e+01 -1.172194e+02  3.346207e+01 -1.177543e+02
# 50%    2.000000e+00  3.582397e+01 -8.776662e+01  3.618349e+01 -8.802789e+01
# 75%    2.000000e+00  4.008496e+01 -8.035368e+01  4.017892e+01 -8.024709e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  7.728394e+06    7.564541e+06   5.729375e+06  7.554250e+06
# mean   5.618423e-01    6.166329e+01   5.825105e+01  6.483104e+01
# std    1.776811e+00    1.901365e+01   2.238983e+01  2.282097e+01
# min    0.000000e+00   -8.900000e+01  -8.900000e+01  1.000000e+00
# 25%    0.000000e+00    4.900000e+01   4.300000e+01  4.800000e+01
# 50%    3.000000e-02    6.400000e+01   6.200000e+01  6.700000e+01
# 75%    4.640000e-01    7.600000e+01   7.500000e+01  8.400000e+01
# max    4.417500e+02    2.070000e+02   2.070000e+02  1.000000e+02
#
#        Pressure(in)  Visibility(mi)  Wind_Speed(mph)  Precipitation(in)
# count  7.587715e+06    7.551296e+06     7.157161e+06       5.524808e+06
# mean   2.953899e+01    9.090376e+00     7.685490e+00       8.407210e-03
# std    1.006190e+00    2.688316e+00     5.424983e+00       1.102246e-01
# min    0.000000e+00    0.000000e+00     0.000000e+00       0.000000e+00
# 25%    2.937000e+01    1.000000e+01     4.600000e+00       0.000000e+00
# 50%    2.986000e+01    1.000000e+01     7.000000e+00       0.000000e+00
# 75%    3.003000e+01    1.000000e+01     1.040000e+01       0.000000e+00
# max    5.863000e+01    1.400000e+02     1.087000e+03       3.647000e+01

# %%
missing_percentage = df.isna().sum().sort_values(ascending = False) / len(df)
a = missing_percentage[missing_percentage!= 0]
a.plot(kind='barh')
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# ID                             0
# Source                         0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  3402762
# End_Lng                  3402762
# Distance(mi)                   0
# Description                    5
# Street                     10869
# City                         253
# County                         0
# State                          0
# Zipcode                     1915
# Country                        0
# Timezone                    7808
# Airport_Code               22635
# Weather_Timestamp         120228
# Temperature(F)            163853
# Wind_Chill(F)            1999019
# Humidity(%)               174144
# Pressure(in)              140679
# Visibility(mi)            177098
# Wind_Direction            175206
# Wind_Speed(mph)           571233
# Precipitation(in)        2203586
# Weather_Condition         173459
# Amenity                        0
# Bump                           0
# Crossing                       0
# Give_Way                       0
# Junction                       0
# No_Exit                        0
# Railway                        0
# Roundabout                     0
# Station                        0
# Stop                           0
# Traffic_Calming                0
# Traffic_Signal                 0
# Turning_Loop                   0
# Sunrise_Sunset             23246
# Civil_Twilight             23246
# Nautical_Twilight          23246
# Astronomical_Twilight      23246
# dtype: int64

# %%
missing_data_per = df.isna().sum().sort_values(ascending=False) / len(df) * 100

# %%
missing_data_per
# Out:
# End_Lat                  44.029355
# End_Lng                  44.029355
# Precipitation(in)        28.512858
# Wind_Chill(F)            25.865904
# Wind_Speed(mph)           7.391355
# Visibility(mi)            2.291524
# Wind_Direction            2.267043
# Humidity(%)               2.253301
# Weather_Condition         2.244438
# Temperature(F)            2.120143
# Pressure(in)              1.820288
# Weather_Timestamp         1.555666
# Nautical_Twilight         0.300787
# Civil_Twilight            0.300787
# Sunrise_Sunset            0.300787
# Astronomical_Twilight     0.300787
# Airport_Code              0.292881
# Street                    0.140637
# Timezone                  0.101030
# Zipcode                   0.024779
# City                      0.003274
# Description               0.000065
# Traffic_Signal            0.000000
# Roundabout                0.000000
# Station                   0.000000
# Stop                      0.000000
# Traffic_Calming           0.000000
# Country                   0.000000
# Turning_Loop              0.000000
# No_Exit                   0.000000
# End_Time                  0.000000
# Start_Time                0.000000
# Severity                  0.000000
# Railway                   0.000000
# Crossing                  0.000000
# Junction                  0.000000
# Give_Way                  0.000000
# Bump                      0.000000
# Amenity                   0.000000
# Start_Lat                 0.000000
# Start_Lng                 0.000000
# Distance(mi)              0.000000
# Source                    0.000000
# County                    0.000000
# State                     0.000000
# ID                        0.000000
# dtype: float64

# %%
missing_data_per[missing_data_per!=0].plot(kind='barh')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
len(df.City.unique())
# Out:
# 13679

# %%
states = df.State.unique()
len(states)
# Out:
# 49

# %%
cities_with_state = df.groupby(['State','City']).size().reset_index(name='count')
cities_with_state
# Out:
#       State        City  count
# 0        AL   Abbeville     37
# 1        AL  Adamsville     25
# 2        AL     Addison     12
# 3        AL       Adger      1
# 4        AL   Alabaster    567
# ...     ...         ...    ...
# 20318    WY   Wamsutter    363
# 20319    WY   Wheatland     91
# 20320    WY      Wilson     20
# 20321    WY     Worland      1
# 20322    WY       Yoder      2
#
# [20323 rows x 3 columns]

# %%
cities_by_state = df.groupby(['City']).size().reset_index(name='count')
cities_by_state
# Out:
#                City  count
# 0        Aaronsburg     21
# 1         Abbeville    604
# 2        Abbotsford     21
# 3            Abbott     33
# 4       Abbottstown    118
# ...             ...    ...
# 13673       Zortman     12
# 13674  Zumbro Falls     74
# 13675      Zumbrota    538
# 13676          Zuni     68
# 13677       Zwingle     14
#
# [13678 rows x 2 columns]

# %%
only_state = df.groupby(['State']).size().reset_index(name='count')
only_state
# Out:
#    State    count
# 0     AL   101044
# 1     AR    22780
# 2     AZ   170609
# 3     CA  1741433
# 4     CO    90885
# 5     CT    71005
# 6     DC    18630
# 7     DE    14097
# 8     FL   880192
# 9     GA   169234
# 10    IA    26307
# 11    ID    11376
# 12    IL   168958
# 13    IN    67224
# 14    KS    20992
# 15    KY    32254
# 16    LA   149701
# 17    MA    61996
# 18    MD   140417
# 19    ME     2698
# 20    MI   162191
# 21    MN   192084
# 22    MO    77323
# 23    MS    15181
# 24    MT    28496
# 25    NC   338199
# 26    ND     3487
# 27    NE    28870
# 28    NH    10213
# 29    NJ   140719
# 30    NM    10325
# 31    NV    21665
# 32    NY   347960
# 33    OH   118115
# 34    OK    83647
# 35    OR   179660
# 36    PA   296620
# 37    RI    16971
# 38    SC   382557
# 39    SD      289
# 40    TN   167388
# 41    TX   582837
# 42    UT    97079
# 43    VA   303301
# 44    VT      926
# 45    WA   108221
# 46    WI    34688
# 47    WV    13793
# 48    WY     3757

# %%
cities_by_accidents = df.City.value_counts()
cities_by_accidents
# Out:
# Miami                           186917
# Houston                         169609
# Los Angeles                     156491
# Charlotte                       138652
# Dallas                          130939
#                                  ...
# Benkelman                            1
# Old Appleton                         1
# Wildrose                             1
# Mc Nabb                              1
# American Fork-Pleasant Grove         1
# Name: City, Length: 13678, dtype: int64

# %%
cities_with_state = df.groupby(['State','City']).size().reset_index(name='count')
cities_with_state
# Out:
#       State        City  count
# 0        AL   Abbeville     37
# 1        AL  Adamsville     25
# 2        AL     Addison     12
# 3        AL       Adger      1
# 4        AL   Alabaster    567
# ...     ...         ...    ...
# 20318    WY   Wamsutter    363
# 20319    WY   Wheatland     91
# 20320    WY      Wilson     20
# 20321    WY     Worland      1
# 20322    WY       Yoder      2
#
# [20323 rows x 3 columns]

# %%
cities_by_state = df.groupby(['City']).size().reset_index(name='count')
cities_by_state
# Out:
#                City  count
# 0        Aaronsburg     21
# 1         Abbeville    604
# 2        Abbotsford     21
# 3            Abbott     33
# 4       Abbottstown    118
# ...             ...    ...
# 13673       Zortman     12
# 13674  Zumbro Falls     74
# 13675      Zumbrota    538
# 13676          Zuni     68
# 13677       Zwingle     14
#
# [13678 rows x 2 columns]

# %%
cities_by_accidents = df.City.value_counts()
cities_by_accidents
# Out:
# Miami                           186917
# Houston                         169609
# Los Angeles                     156491
# Charlotte                       138652
# Dallas                          130939
#                                  ...
# Benkelman                            1
# Old Appleton                         1
# Wildrose                             1
# Mc Nabb                              1
# American Fork-Pleasant Grove         1
# Name: City, Length: 13678, dtype: int64

# %%
Which States have Highest number of accidents?

# %%
states_by_accidents = df.State.value_counts()
states_by_accidents
# Out:
# CA    1741433
# FL     880192
# TX     582837
# SC     382557
# NY     347960
# NC     338199
# VA     303301
# PA     296620
# MN     192084
# OR     179660
# AZ     170609
# GA     169234
# IL     168958
# TN     167388
# MI     162191
# LA     149701
# NJ     140719
# MD     140417
# OH     118115
# WA     108221
# AL     101044
# UT      97079
# CO      90885
# OK      83647
# MO      77323
# CT      71005
# IN      67224
# MA      61996
# WI      34688
# KY      32254
# NE      28870
# MT      28496
# IA      26307
# AR      22780
# NV      21665
# KS      20992
# DC      18630
# RI      16971
# MS      15181
# DE      14097
# WV      13793
# ID      11376
# NM      10325
# NH      10213
# WY       3757
# ND       3487
# ME       2698
# VT        926
# SD        289
# Name: State, dtype: int64

# %% [markdown]
# Top 5 cities that have Highest number of accidents?

# %%
cities_by_accidents[:5]
# Out:
# Miami          186917
# Houston        169609
# Los Angeles    156491
# Charlotte      138652
# Dallas         130939
# Name: City, dtype: int64

# %% [markdown]
# Top 5 States that have Highest number of accidents?

# %%
states_by_accidents[:5]
# Out:
# CA    1741433
# FL     880192
# TX     582837
# SC     382557
# NY     347960
# Name: State, dtype: int64

# %% [markdown]
# Top 5 cities that have lowest number of accidents

# %%
cities_by_accidents[::-1][:5]
# Out:
# American Fork-Pleasant Grove    1
# Mc Nabb                         1
# Wildrose                        1
# Old Appleton                    1
# Benkelman                       1
# Name: City, dtype: int64

# %% [markdown]
# Plotting Which States have Highest number of accidents

# %%
states_by_accidents[:20].plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# Plotting Which Cities have Highest number of accidents?

# %%
cities_by_accidents[:20].plot(kind='barh')
# Out:
# <Axes: >

# %%
sns.set_style('whitegrid')

# %% [markdown]
# Plotting the trend of number of accident ( exponenetial increase or decrease)

# %%
sns.distplot(cities_by_accidents)
# Out:
# C:\Users\Kunal\AppData\Local\Temp\ipykernel_9880\1083794035.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cities_by_accidents)
# <Axes: xlabel='City', ylabel='Density'>

# %% [markdown]
# hreshold for High and low number of accidents

# %%
high_accidents_cities = cities_by_accidents[cities_by_accidents>=1000]
low_accidents_cities = cities_by_accidents[cities_by_accidents<1000]

# %% [markdown]
# Percantage of Cities which have Highest number of accidents?

# %%
len(high_accidents_cities)/len(df.City)*100
# Out:
# 0.015760066062884475

# %% [markdown]
# Plotting those Cities which have Highest number of accidents?

# %%
sns.displot(high_accidents_cities)

# %% [markdown]
# Plotting those Cities which have lowest number of accidents?

# %%
sns.distplot(low_accidents_cities)
# Out:
# C:\Users\Kunal\AppData\Local\Temp\ipykernel_9880\3909798328.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(low_accidents_cities)
# <Axes: xlabel='City', ylabel='Density'>

# %% [markdown]
# Plotting the overall ratio of accidents?

# %%
sns.histplot(cities_by_accidents, log_scale=True)
# Out:
# <Axes: xlabel='City', ylabel='Count'>

# %%
df.Start_Time[0]
# Out:
# Timestamp('2016-02-08 05:46:00')

# %%
df.Start_Time = pd.to_datetime(df.Start_Time)

# %%
df.Start_Time[0]
# Out:
# Timestamp('2016-02-08 05:46:00')

# %% [markdown]
# The Hours during which have Highest number of accidents in a day?

# %%
sns.histplot(df.Start_Time.dt.hour,bins=24)
# Out:
# <Axes: xlabel='Start_Time', ylabel='Count'>

# %%
sns.distplot(df.Start_Time.dt.hour,bins=24)
# Out:
# C:\Users\Kunal\AppData\Local\Temp\ipykernel_9880\779488143.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.hour,bins=24)
# <Axes: xlabel='Start_Time', ylabel='Density'>

# %% [markdown]
# The days during which have Highest number of accidents in a week?

# %%
sns.distplot(df.Start_Time.dt.dayofweek,bins=7, kde=False,norm_hist=True)
# Out:
# C:\Users\Kunal\AppData\Local\Temp\ipykernel_9880\362580169.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.dayofweek,bins=7, kde=False,norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %% [markdown]
# How many Accidents occured on Sunday?

# %%
sunday_start_time = df.Start_Time[df.Start_Time.dt.dayofweek == 6]
sns.displot(sunday_start_time.dt.hour, bins=24, kde=False)

# %%
Exploratory Data Anaylsis
1.City
2.Start Time
3.Day of week
4.Weekend
5.Month
6.Start Latitude & Longitude

# %%
len(df.City.unique())
# Out:
# 13679

# %%
a = df[["City","Severity"]].groupby('City').mean().sort_values('Severity',ascending = False)
a[:20].plot(kind='barh')
plt.title("Cities with accident severity rate 4")
plt.xlabel("Severity")
plt.show()

# %%
city_accidents = df.City.value_counts()
plt.figure(figsize = (10,10))
city_accidents[:20].plot(kind = 'barh')
plt.title("20 cities with the most accidents in the US")
plt.xlabel("Number of Accidents")
plt.ylabel("Cities")
plt.show()

# %%
plt.figure(figsize = (9,3))
sns.distplot(city_accidents)
plt.title("Distrubution of the accidents")
plt.xlabel("Number of Accidents")
plt.show()
# Out:
# C:\Users\Kunal\AppData\Local\Temp\ipykernel_9880\5253190.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(city_accidents)

# %%
high_accident_cities = city_accidents[city_accidents >=1000]
low_accident_cities = city_accidents[city_accidents<1000]
plt.figure(figsize = (9,3))
sns.distplot(high_accident_cities)
plt.title("Density of Cities With High Accident Rates")
plt.xlabel("Number of Accidents")
plt.show()
# Out:
# C:\Users\Kunal\AppData\Local\Temp\ipykernel_9880\1718461270.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(high_accident_cities)

# %%
plt.figure(figsize = (9,3))
sns.distplot(low_accident_cities)
plt.title("Density of Cities With Low Accident Rates")
plt.xlabel("Number of Accidents")
plt.show()
# Out:
# C:\Users\Kunal\AppData\Local\Temp\ipykernel_9880\511085296.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(low_accident_cities)

# %%
len(high_accident_cities) / len(df.City.unique())
# Out:
# 0.08904159660793917

# %%
len(low_accident_cities) / len(df.City.unique())
# Out:
# 0.910885298632941

# %%
city_accidents[city_accidents ==1].sum()
# Out:
# 1023

# %% [markdown]
# Only one accident in each of 1100 cities

# %% [markdown]
# Start Time

# %%
df.Start_Time = pd.to_datetime(df.Start_Time)

# %%
sns.distplot(df.Start_Time.dt.hour, bins = 24, norm_hist = True )
plt.title("Distribution of Accidents")
plt.ylabel('Percentage')
plt.show()
# Out:
# C:\Users\Kunal\AppData\Local\Temp\ipykernel_9880\583061658.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.hour, bins = 24, norm_hist = True )

# %% [markdown]
# It seems that accidents start to intensify between 05:00 and 07:00. Here we can infer that traffic is heavy and people are most likely on their way to work. This explains the high rate of accidents. We have the highest accident rate between 16.00 and 18.00. This is generally during rush hour and has the highest traffic volume during the day. From this point, we can say that it is logical that the highest accidents occur between these hours.

# %% [markdown]
# Day of Week

# %%
sns.distplot(df.Start_Time.dt.dayofweek, bins = 7,kde =False, norm_hist = True )
plt.show()
# Out:
# C:\Users\Kunal\AppData\Local\Temp\ipykernel_9880\2294872589.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.dayofweek, bins = 7,kde =False, norm_hist = True )

# %%
Weekend

# %%
weekend = df[(df.Start_Time.dt.dayofweek == 6) | (df.Start_Time.dt.dayofweek == 7)]
sns.distplot(weekend.Start_Time.dt.hour, bins = 24, norm_hist = True )
plt.ylabel('Percentage')
plt.show()
# Out:
# C:\Users\Kunal\AppData\Local\Temp\ipykernel_9880\3635001849.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(weekend.Start_Time.dt.hour, bins = 24, norm_hist = True )

# %% [markdown]
# As expected, the accident rate is much lower in the morning hours compared to the whole week. The biggest reason for this may be that people sleep in the mornings during the weekend. It makes sense that accident rates increase in the afternoon because people are out and about doing activities. The reason why the accident rate is still higher at night than on normal days could be because people are driving drunk.

# %%
Month

# %%
sns.distplot(df.Start_Time.dt.month, bins = 12, kde = False,  norm_hist = True )
plt.ylabel('Percentage')
plt.show()
# Out:
# C:\Users\Kunal\AppData\Local\Temp\ipykernel_9880\1157588747.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.month, bins = 12, kde = False,  norm_hist = True )

# %% [markdown]
# It seems that we have an issue. To figure it out we can check the distrubution of each year.

# %%
df_2016 = df[df.Start_Time.dt.year == 2016]
df_2017 = df[df.Start_Time.dt.year == 2017]
df_2018 = df[df.Start_Time.dt.year == 2018]
df_2019 = df[df.Start_Time.dt.year == 2019]
df_2020 = df[df.Start_Time.dt.year == 2020]
df_2021 = df[df.Start_Time.dt.year == 2021]

# %%
sns.distplot(df_2016.Start_Time.dt.month, bins = 12, kde = False,  norm_hist = True )
plt.ylabel('Percentage')
plt.show()
# Out:
# C:\Users\Kunal\AppData\Local\Temp\ipykernel_9880\3281219207.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2016.Start_Time.dt.month, bins = 12, kde = False,  norm_hist = True )

# %%
sns.distplot(df_2017.Start_Time.dt.month, bins = 12, kde = False,  norm_hist = True )
plt.ylabel('Percentage')
plt.show()
# Out:
# C:\Users\Kunal\AppData\Local\Temp\ipykernel_9880\3311661628.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2017.Start_Time.dt.month, bins = 12, kde = False,  norm_hist = True )

# %%
sns.distplot(df_2018.Start_Time.dt.month, bins = 12, kde = False,  norm_hist = True )
plt.ylabel('Percentage')
plt.show()
# Out:
# C:\Users\Kunal\AppData\Local\Temp\ipykernel_9880\521025089.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2018.Start_Time.dt.month, bins = 12, kde = False,  norm_hist = True )

# %%
sns.distplot(df_2019.Start_Time.dt.month, bins = 12, kde = False,  norm_hist = True )
plt.ylabel('Percentage')
plt.show()
# Out:
# C:\Users\Kunal\AppData\Local\Temp\ipykernel_9880\2902951798.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2019.Start_Time.dt.month, bins = 12, kde = False,  norm_hist = True )

# %%
sns.distplot(df_2020.Start_Time.dt.month, bins = 12, kde = False,  norm_hist = True )
plt.ylabel('Percentage')
plt.show()
# Out:
# C:\Users\Kunal\AppData\Local\Temp\ipykernel_9880\2022667815.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2020.Start_Time.dt.month, bins = 12, kde = False,  norm_hist = True )

# %%
sns.distplot(df_2021.Start_Time.dt.month, bins = 12, kde = False,  norm_hist = True )
plt.ylabel('Percentage')
plt.show()
# Out:
# C:\Users\Kunal\AppData\Local\Temp\ipykernel_9880\586775224.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2021.Start_Time.dt.month, bins = 12, kde = False,  norm_hist = True )

# %% [markdown]
# After looking the distrubution of each year we can understand the issue. Probably not enough data was collected for each year. We understand this from this: Look at years like 2016, 2019 and 2020. It is easy to see that data is missing for some months. This explains the lack of a regular distribution

# %% [markdown]
# 3. Start Latitude & Longitude

# %%
sns.scatterplot(x = df.Start_Lng, y = df.Start_Lat)
# Out:
# <Axes: xlabel='Start_Lng', ylabel='Start_Lat'>

# %% [markdown]
# When we look at the latitude and longitude of the accidents, we can see that the accidents are distributed in a way similar to the map of America. This is not a surprising result, assuming that the accidents happened in America.

# %%
Map of US whhich shows the severity of the accidents.

# %%
sns.scatterplot(x=df.Start_Lng,y=df.Start_Lat,data=df,size=df.Severity, hue=df.Severity)
# Out:
# <Axes: xlabel='Start_Lng', ylabel='Start_Lat'>

# %% [markdown]
# Summary & Conclusion
# The number of accidents in the US is increasing every year with percentchange of 75% on average.
# The top 5 states with the highest number of accidents are:
# California
# Florida
# Texas
# Oregan
# Virginica ### the top 5 states with the lowest number of accidents are:
# Washington
# Oregon
# California
# Texas
# New York ### top 5 cities with the highest number of accidents are:
# Miami
# Los Angeles
# Orlando
# Denise
# Houstan

# %% [markdown]
# Some other useful insights:
# On Working Days(Mon-Fri) the number of accidents is higher than on weekends.
# Only 0.017% of the states have high ratio of accident (i.e greater > 1000)
# Most of the accidentd reported on morining and eveing timing, but compartively number od accident in evening timeing is much greater.
# Onweekends the number of accidents in morning drastically decreases.
# Most accidents are observed when the temprature is in between 50 and 80 farenheit.
# The trend of increase or decrease in accident is exponentail.
